# %% [markdown]
# **Trabalho prático 2 - Modulo 2 do Bootcamp Analista de Machine Learning da IGTI**

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Lendo o dataset com a biblioteca pandas

# %%
df = pd.read_csv('/content/drive/My Drive/Data Science/IGTI Bootcamp/Modulo 2/Trabalho Pratico 2/KaggleV2-May-2016.csv')

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender  ... Handcap SMS_received  No-show
# 0  2.987250e+13        5642903      F  ...       0            0       No
# 1  5.589978e+14        5642503      M  ...       0            0       No
# 2  4.262962e+12        5642549      F  ...       0            0       No
# 3  8.679512e+11        5642828      F  ...       0            0       No
# 4  8.841186e+12        5642494      F  ...       0            0       No
#
# [5 rows x 14 columns]

# %% [markdown]
# ### Qual é a proporção aproximada de pacientes que compareceram à consulta?

# %% [markdown]
# 80% compareceram à consulta

# %%
df['No-show'].value_counts() / len(df['No-show'])
# Out:
# No     0.798067
# Yes    0.201933
# Name: No-show, dtype: float64

# %% [markdown]
# ### Quantas instâncias e atributos existem no dataset, respectivamente?

# %% [markdown]
# 110527 Linhas e 14 Colunas

# %%
df.shape
# Out:
# (110527, 14)

# %% [markdown]
# ### Qual das colunas do dataset possuem valores nulos?

# %% [markdown]
# Reposta = Nenhuma

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %% [markdown]
# ### Qual é a idade média dos pacientes?

# %% [markdown]
# A média é de 37 anos

# %%
df.Age.mean()
# Out:
# 37.08887421173107

# %% [markdown]
# ### Em quantas localidades diferentes (Neighbourhood) os pacientes residem?

# %% [markdown]
# 81 localidades diferentes

# %%
df.Neighbourhood.nunique()
# Out:
# 81

# %% [markdown]
# ### Comparando apenas a identificação do paciente (PatientId) com o número dos agendamentos das consultas (AppointmentID) o que podemos inferir?

# %% [markdown]
# Existem pacientes que realizam mais de 1 atendimento.

# %%
df.groupby('PatientId')['AppointmentID'].count().sort_values(ascending=False)
# Out:
# PatientId
# 8.221459e+14    88
# 9.963767e+10    84
# 2.688613e+13    70
# 3.353478e+13    65
# 7.579746e+13    62
#                 ..
# 5.296582e+13     1
# 5.295720e+13     1
# 5.295287e+13     1
# 5.293546e+13     1
# 3.921784e+04     1
# Name: AppointmentID, Length: 62299, dtype: int64

# %% [markdown]
# ### Quantas variáveis binárias (apenas dois valores) existem no dataset?

# %% [markdown]
# Existem 7 variáveis binarias

# %%
df.nunique().sort_values()
# Out:
# Gender                 2
# Scholarship            2
# Hipertension           2
# Diabetes               2
# Alcoholism             2
# SMS_received           2
# No-show                2
# Handcap                5
# AppointmentDay        27
# Neighbourhood         81
# Age                  104
# PatientId          62299
# ScheduledDay      103549
# AppointmentID     110527
# dtype: int64

# %% [markdown]
# ### Quantos valores diferentes encontramos para a variável dos SMS recebidos (SMS_received)?

# %% [markdown]
# Existem 2 variáveis

# %%
df['SMS_received'].nunique()
# Out:
# 2

# %% [markdown]
# ### Qual é a menor e maior idade, respectivamente, presente no dataset?

# %%
df.Age.describe()
# Out:
# count    110527.000000
# mean         37.088874
# std          23.110205
# min          -1.000000
# 25%          18.000000
# 50%          37.000000
# 75%          55.000000
# max         115.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### Qual é a proporção de pacientes que receberam o sms e NÃO compareceram?

# %% [markdown]
# 27% não compareceram e receberam SMS

# %%
df['No-show'].value_counts()['Yes']
# Out:
# 22319

# %%
df['No-show'].value_counts()['Yes']
# Out:
# 0    75045
# 1    35482
# Name: SMS_received, dtype: int64

# %%
df['No-show'].value_counts()['Yes'] | df['SMS_received'].value_counts()
# Out:
# 0    96047
# 1    57279
# Name: SMS_received, dtype: int64

# %%
sms = df.groupby('SMS_received')['No-show'].value_counts() / len(df['SMS_received'])
sms
# Out:
# SMS_received  No-show
# 0             No         0.565563
#               Yes        0.113411
# 1             No         0.232504
#               Yes        0.088521
# Name: No-show, dtype: float64

# %%
9784 + 25698
# Out:
# 35482

# %%
9784 / 35482
# Out:
# 0.27574544839637

# %% [markdown]
# ### Qual região possui o maior número de consultas marcadas?

# %% [markdown]
# Região de Jardim Camburi possui mais consultas marcadas

# %%
df['Neighbourhood'].value_counts()
# Out:
# JARDIM CAMBURI                 7717
# MARIA ORTIZ                    5805
# RESISTÊNCIA                    4431
# JARDIM DA PENHA                3877
# ITARARÉ                        3514
#                                ...
# ILHA DO BOI                      35
# ILHA DO FRADE                    10
# AEROPORTO                         8
# ILHAS OCEÂNICAS DE TRINDADE       2
# PARQUE INDUSTRIAL                 1
# Name: Neighbourhood, Length: 81, dtype: int64
